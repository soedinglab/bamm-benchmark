# %%
from mpl_stylesheet import statPlots

# %%
idir_diffcell = "../../data/processed/crossCLs/"
odir_figure = "../../figures/"

sfx_time = ".time.bench"
sfx_score = ".bmscore.bench"

# %%
datasets = [
    "bammk5_full",
    "bammk5_mask",
    "bammk1_mask",
    "inmode",
    "dichipmunk",
    "chipmunk",
    "meme",
    "cisfinder",
]

labels = [
    "BaMM($5^{th}$,full)",
    "BaMM($5^{th}$)",
    "BaMM($1^{st}$)",
    "InMoDe($2^{nd}$)",
    "diChIPMunk",
    "ChIPMunk",
    "MEME",
    "CisFinder",
]

# %%
scores_cl = [] # cross-cell-line validation

for data in datasets:
    scores_cl.append(idir_diffcell+data+sfx_score)
    
args_cl =  {
         "scores" : scores_cl,
         "labels" : labels,
         "ytick_dual": (0.5,0.6,0.7),
         "ytick_scatter" : (0.5,1,2,4,8), 
         "yticklabel_scatter" : (-1,0,1,2,3), 
         "ylabel_scatter" : 'AvRec log$_{2}$(fc), $5^{th}$ BaMM',
         "title" : "ChIP model (n=238)",
}

# %%
args_cl['pstyle'] = "scatter"
args_cl["diselect"] = [labels[6], labels[0]]
args_cl['xlabel_scatter'] = 'AvRec score, MEME'
args_cl['save_fn'] = odir_figure + 'cl_scatterplot_3.pdf'
args_cl['legend'] = False
args_cl['xtick'] = ()
statPlots(args_cl)
# Out:
# There are 8 tools. Each has 238(304) data sets.

# %%
args_cl["diselect"] = [labels[3], labels[0]]
args_cl['xlabel_scatter'] = 'AvRec score, InMoDe'
args_cl['save_fn'] = odir_figure + 'cl_scatterplot_1.pdf'
args_cl['legend'] = False
args_cl['xtick'] = ()
statPlots(args_cl)
# Out:
# There are 8 tools. Each has 238(304) data sets.

# %%
args_cl["diselect"] = [labels[4], labels[0]]
args_cl['xlabel_scatter'] = 'AvRec score, di-ChIPMunk'
args_cl['save_fn'] = odir_figure + 'cl_scatterplot_2.pdf'
args_cl['legend'] = False
args_cl['xtick'] = ()
statPlots(args_cl)
# Out:
# There are 8 tools. Each has 238(304) data sets.
